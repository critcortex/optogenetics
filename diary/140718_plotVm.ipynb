# %%
import pylab
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# ### Current injection

# %%
#dat = np.loadtxt('/home/sjarvis1/git/optogenetics/140718_replaylong_replay_current_NpHR_none_ChR_none_v.dat')
#dat = np.loadtxt('/home/sjarvis1/git/optogenetics/140718_replaylong_replay_current_Ia2_NpHR_none_ChR_none_v.dat')
dat = np.loadtxt('/home/sjarvis1/git/optogenetics/experiments/140718_replaylong/dat/140718_replaylong_replay_current_Ia5_freq50_NpHR_none_ChR_none_v.dat')

# %%
pylab.figure()
pylab.plot(dat[0],dat[1])
pylab.xlim(2000,4000)
pylab.show()

# %% [markdown]
# ### Current with biphasic injection

# %%
dat_bi = np.loadtxt('/home/sjarvis1/git/optogenetics/experiments/140718_replaylong/dat/140718_replaylong_replay_current_biphasic_Ia5_freq50_NpHR_none_ChR_none_v.dat')

# %%
pylab.figure()
pylab.plot(dat_bi[0],dat_bi[1])
pylab.xlim(2000,4000)
pylab.show()

# %% [markdown]
# ### Optogenetics

# %%
#opt = np.loadtxt('/home/sjarvis1/git/optogenetics/140718_replaylong_replay_optogen_NpHR_whole_ChR_whole_v.dat')
#opt = np.loadtxt('/home/sjarvis1/git/optogenetics/140718_replaylong_replay_optogen_irr0.002_NpHR_whole_ChR_whole_v.dat')
#opt = np.loadtxt('/home/sjarvis1/git/optogenetics/140718_replaylong_replay_optogen_irr0.008_factor0.10_NpHR_whole_ChR_whole_v.dat')
opt = np.loadtxt('/home/sjarvis1/git/optogenetics/experiments/140718_replaylong/dat/140718_replaylong_replay_optogen_irr0.007_factor0.10_freq50_NpHR_whole_ChR_whole_v.dat')

# %%
pylab.figure()
pylab.plot(opt[0],opt[1])
pylab.xlim(2000,4000)
pylab.show()

# %% [markdown]
# ### Normal

# %%
norm = np.loadtxt('/home/sjarvis1/git/optogenetics/experiments/140718_replaylong/dat/140718_replaylong_replay_normal_freq50_NpHR_none_ChR_none_v.dat')

# %%
pylab.figure()
pylab.plot(norm[0],norm[1])
pylab.xlim(2000,4000)
pylab.show()

# %% [markdown]
# ### Pretty plotting:

# %%
xlim = (1800,4000)
ylim = (-90,20)

# %%
pylab.figure(figsize=(9,3))
pylab.plot(norm[0],norm[1],'k',lw=1.5)
pylab.xlim(xlim)
pylab.ylim(ylim)
pylab.axis('off')
pylab.savefig('intro_normal.png',dpi=300,transparent=True)

# %%
pylab.figure(figsize=(9,3))
pylab.plot(opt[0],opt[1],c='#666666',lw=1.5)
pylab.xlim(xlim)
pylab.ylim(ylim)
pylab.axis('off')
pylab.savefig('intro_loose.png',dpi=300,transparent=True)

# %%
pylab.figure(figsize=(9,3))
pylab.plot(dat[0],dat[1],c='#333333',lw=1.5)
pylab.xlim(xlim)
pylab.ylim(ylim)
pylab.axis('off')
pylab.savefig('intro_hard.png',dpi=300,transparent=True)
