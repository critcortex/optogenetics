# %%
import numpy as np
import pylab
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
dat = np.loadtxt('../140305_compare_equal_branchesirr5.0_factor0.12_nb2_ns2_nl6_spikes50_loc0_NpHR_whole_ChR_whole_v.dat')

# %%
print len(dat)
vsoma = dat[1,:]
tlight = dat[0,:]

pylab.plot(tlight,vsoma,'k')
pylab.savefig('140305_compare_equal_spikes_entire.png')
# Out:
# 8

# %%
ts = dat[0,:]
print len(ts), 
t_from = len(ts)/3
t_end = 8000
vsoma = dat[1,t_from:t_end+t_from]
tlight = dat[0,t_from:t_end+t_from]

pylab.plot(tlight,vsoma,'k')
pylab.savefig('140305_compare_equal_spikes_vsoma_activation.png')
# Out:
# 120001

# %%
vdend0 = dat[2,t_from:t_end+t_from]
pylab.plot(tlight,vdend0,'#888888')
pylab.savefig('140305_compare_equal_spikes_dend0_activation.png')

# %%
vdend1 = dat[-1,t_from:t_end+t_from]
pylab.plot(tlight,vdend1,'b')
pylab.savefig('140305_compare_equal_spikes_dend1_activation.png')
